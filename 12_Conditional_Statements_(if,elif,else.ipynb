# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/12_Conditional_Statements_(if%2Celif%2Celse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***if statement***

# %%
age=20
if age>=18:
  print("You can vote")
# Out:
# You can vote

# %%
age>=18
# Out:
# True

# %%
age=16
if age>=18:
  print("You are eligible for voting")
else:
  print("You are minor")
# Out:
# You are minor

# %% [markdown]
# **elif statement**

# %%
## The elif statement allow u to check multiple conditions stands for else-if
age=23
if age<=13:
  print("You are a child")
elif age<=18:
  print("You are a teenager")
else:
  print("You are adult")
# Out:
# You are adult

# %%
## To check if the number is positive ,negative, odd or even
num=int(input("Enter the number here:"))
if num>0:
  print("The number is positive")
  if num%2==0:
    print("The number is even")
  else:
    print("The number is odd")
else:
  print("The number is zero or  negative")
# Out:
# Enter the number here:-7
# The number is zero or  negative

# %%
## to determine if the year is leap year
year=int(input("Enter the year here:"))
if year%4==0:
  if year%100==0:
    if year %400==0:
      print(year, "is a leap year")
    else:
      print(year,"is not  a leap year")
  else:
    print(year,"is a leap year")
else:
  print(year,"is not a leap year")
# Out:
# Enter the year here:456
# 456 is a leap year
