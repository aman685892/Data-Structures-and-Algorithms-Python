# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/11_Operators_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Arithmetic operation
a=10
b=5
addition=a+b
subtraction=a-b
multiplication=a*b
division=a/b
floor_division=a//b
Modulus=a%b
Exponent=a**b

print(addition)
print(subtraction)
print(multiplication)
print(division)
print(floor_division)
print(Modulus)
print(Exponent)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
##comparison operators
## == caleed as equal to operators
a=10
b=10
print(a==b)
# Out:
# True

# %%
str1="aman"
str2="kumar"
str1==str2
# Out:
# False

# %%
str1="aman"
str2="aman"
str1==str2
# Out:
# True

# %%
## Not equal to (!=) operators
str3="prashant"
str4="amit"
str3!=str4
# Out:
# True

# %%
## greater than >
a=24
b=67
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
## greater than equal to
x=89
y=78
x>=y
# Out:
# True

# %%
## Less than or equal to
m=89
n=78
m<=n
# Out:
# False

# %%
## Logical operators
## and,or,not
x=True
y=False
x and y
# Out:
# False

# %%
print(x or y)
# Out:
# True

# %%
num1=67
num2=68
if (num1==num2) and (num1>num2):
  print("aman")
print("Hello")
# Out:
# Hello

# %%
## not operator
a=False
not a
# Out:
# True

# %%
from ast import Yield
##  simple calculator
x=float(input("Enter the number x:"))
y=float(input("Enter the number y:"))
sum=x+y
diff=x-y
mul=x*y
div=x/y
floor_div=x//y
Remainder=x%y
print(sum)
print(diff)
print(mul)
print(div)
print(floor_div)
print(Remainder)
# Out:
# Enter the number x:23.6
# Enter the number y:5.0
# 28.6
# 18.6
# 118.0
# 4.720000000000001
# 4.0
# 3.6000000000000014
