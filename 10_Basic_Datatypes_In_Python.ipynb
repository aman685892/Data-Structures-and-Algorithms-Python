# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/10_Basic_Datatypes_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## integer data type
age=21
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
## floating point
height=7.8
print(height,type(height))
# Out:
# 7.8 <class 'float'>

# %%
## string type
name="aman"
print(name,type(name))
# Out:
# aman <class 'str'>

# %%
Is_true=True
print(Is_true)
print(type(Is_true))
# Out:
# True
# <class 'bool'>

# %%
a=10
b=10
a==b
print(type(a==b))
# Out:
# <class 'bool'>

# %%
## common errors
result= "Hello"+str(6)
print(result)
# Out:
# Hello6
