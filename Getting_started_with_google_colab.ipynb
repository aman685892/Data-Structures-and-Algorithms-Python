# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/Getting_started_with_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+5
# Out:
# 7

# %%
print("hello")
# Out:
# hello

# %%
list=[2,3,4,5]
print(list)
# Out:
# [2, 3, 4, 5]

# %%
print(2+5)
# Out:
# 7
