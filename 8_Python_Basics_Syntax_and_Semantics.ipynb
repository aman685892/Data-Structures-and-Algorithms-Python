# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/8_Python_Basics_Syntax_and_Semantics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## basic syntax rules in python
## Case sensitivity- Python is a case sensitive language

# %%
name="aman"
Name="prashant"
print(name)
print(Name)
# Out:
# aman
# prashant

# %%
## Indentation
age=32
if age>30:
  print(age) ## here is indentation inside blocks
print(age)
# Out:
# 32
# 32

# %%
## single line commnets
## LINE continuation using backslash \
total=1+2+3+4+5+6+7+\
8+9
print(total)
# Out:
# 45

# %%
## Multiple statements on a single line
x=8;y=9;z=x+y
print(z)
# Out:
# 17

# %%
## Understanding semantics in python
age=21
name= "aman"
print(type(age)) ## age is an integer
print(type(name)) ## name is string
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Type inference
variable=10
print(type(variable))
variable="aman"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=21
if age>18:
  print(age+1)
print(age)
# Out:
# 22
# 21

# %%
## name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-710111868.py in <cell line: 0>()
#       1 ## name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code examples of indentation
if True:
  print("Correct Indentation")
  if False:
    print("This wont print")
  print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
