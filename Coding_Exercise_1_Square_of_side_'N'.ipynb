# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/Coding_Exercise_1_Square_of_side_'N'.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Square of side 'N'
# Problem Description: You are given an integer n. Your task is to return a square pattern of size n x n made up of the character '*', represented as a list of strings.
#
#
#
# Input Parameters:
#
# n (int): The size of the square (number of rows and columns).
#
#
#
# Output:
#
# A list of strings where each string is a row of n characters.
#
#
#
# Example:
#
# Input: 3
# Output: ['***', '***', '***']
#
# Input: 5
# Output: ['*****', '*****', '*****', '*****', '*****']

# %%
"""
    Function to return a square pattern of '*' of side n as a list of strings.

    Parameters:
    n (int): The size of the square.

    Returns:
    list: A list of strings where each string represents a row of the square.
    """


def generate_square(n):
  lst=[]
  for i in range(n):
    lst.append("*"*n)
  return lst
generate_square(3)
# Out:
# ['***', '***', '***']
