# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/29_Introduction_to_Arrays_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l1=[]
l1.append(1)
l1.append(7)
l1.append("aman")
print(l1)
# Out:
# [1, 7, 'aman']

# %%
import array
arr=array.array('i',[1,2,3,4,5])
print(arr)
arr[0]=56
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])
# array('i', [56, 2, 3, 4, 5])
