# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Structures-and-Algorithms-Python/blob/main/15_Sets_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_set={1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_empty_set=set()
print(type(my_empty_set))
# Out:
# <class 'set'>

# %%
my_empty_set=set([1,2,3,4,5])
print(my_empty_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
## adding and removing elements
my_set.add(8)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3, 5, 8}

# %%
## removing an element if present otherwise ni problem
my_set.discard(34)
print(my_set)
# Out:
# {1, 2, 3, 5, 8}

# %%
y=my_set.pop()
print(y)
print(my_set)
# Out:
# 1
# {2, 3, 5, 8}

# %%
## clear all the elemnets of the set
r=my_set.clear()
print(my_set)
# Out:
# set()

# %%
## set membership test
my_set={1,2,3,45,7,8}
print(4 in my_set)
print(8 in my_set)
print(78 in my_set)
print(45 in my_set)
# Out:
# False
# True
# False
# True

# %%
## mathematical operation in set
## 1.union
set1={1,2,3,4,5,6}
set2={5,6,7,8,9}
print(set1.union(set2))
## intersection
print(set1.intersection(set2))
set1.intersection_update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {5, 6}
# {5, 6}

# %%
set1
# Out:
# {5, 6}

# %%
print(set1)
# Out:
# {5, 6}

# %%
set1={1,2,3,4,5,6}
set2={5,6,7,8,9}
 ## diffrence bewtween 2 sets
x=set1.difference(set2)
print(x)
# Out:
# {1, 2, 3, 4}

# %%
i=set2.difference(set1)
print(i)
# Out:
# {8, 9, 7}

# %%
## symmetric diiference
set1.symmetric_difference(set2)  #3 in symmetric diffrence both the unique elements are combined and intersectio is removed from the given sets
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
set1={1,2,3}
set2={2,3,5}
## set methods
print(set1.issubset(set2))
print(set1.issuperset(set2))
# Out:
# False
# False

# %%
lst=[1,2,3,4,5,5,6]
print(set(lst))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
## counting the unique words in a text
words="Hello, i am learning machine learning and deep learning and mastering ai and recent boomig technology"
words=words.split()
print(words)
# Out:
# ['Hello,', 'i', 'am', 'learning', 'machine', 'learning', 'and', 'deep', 'learning', 'and', 'mastering', 'ai', 'and', 'recent', 'boomig', 'technology']

# %%
print(set(words))
print(len(words))
# Out:
# {'and', 'ai', 'mastering', 'technology', 'i', 'boomig', 'learning', 'machine', 'deep', 'recent', 'Hello,', 'am'}
# 16
